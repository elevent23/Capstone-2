# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
### load the meta data

data = []
with gzip.open('Sports_and_Outdoors_5.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(data))

# first row of the list
print(data[0])
# Out:
# 2839940
# {'overall': 5.0, 'verified': True, 'reviewTime': '06 3, 2015', 'reviewerID': 'A180LQZBUWVOLF', 'asin': '0000032034', 'reviewerName': 'Michelle A', 'reviewText': 'What a spectacular tutu! Very slimming.', 'summary': 'Five Stars', 'unixReviewTime': 1433289600}

# %%
# convert list into pandas dataframe

df = pd.DataFrame.from_dict(data)

print(len(df))
# Out:
# 2839940

# %%
df.head(50)
# Out:
#     overall  verified   reviewTime      reviewerID        asin  \
# 0       5.0      True   06 3, 2015  A180LQZBUWVOLF  0000032034
# 1       1.0      True   04 1, 2015   ATMFGKU5SVEYY  0000032034
# 2       5.0      True  01 13, 2015  A1QE70QBJ8U6ZG  0000032034
# 3       5.0      True  12 23, 2014  A22CP6Z73MZTYU  0000032034
# 4       4.0      True  12 15, 2014  A22L28G8NRNLLN  0000032034
# 5       5.0      True   07 5, 2008   A5N0QU8JBRVQQ  0899332757
# 6       5.0     False   02 7, 2017   ANGLIGXJHXC6D  0899332757
# 7       5.0      True  12 27, 2016   ASAE9FBGAJQAH  0899332757
# 8       3.0      True  12 12, 2016  A1TAW91SQSU2AH  0899332757
# 9       5.0      True  08 13, 2016  A1SVGO4GMEOXQ0  0899332757
# 10      5.0      True   08 2, 2016  A36QT6N7N0GF3O  0899332757
# 11      5.0     False   08 1, 2016    A1LACH6MLQWZ  0899332757
# 12      5.0      True  07 14, 2016   AJGZDX7KC5TVQ  0899332757
# 13      5.0      True  05 29, 2016   ATDEJ6381GRZJ  0899332757
# 14      5.0      True  05 12, 2016  A25OUQTJ7JE1J5  0899332757
# 15      5.0      True  05 11, 2016  A1EEXQY23P5XSE  0899332757
# 16      5.0      True  10 26, 2015  A1IQJSM0YNQJTT  0899332757
# 17      5.0      True   10 7, 2015   AXUAY9M189EJ1  0899332757
# 18      5.0      True  08 24, 2015  A2014T7L0A3W4G  0899332757
# 19      4.0      True   08 4, 2015  A2LBF5LI09BS8Z  0899332757
# 20      5.0      True  05 28, 2015  A11G1FW7QISV3Y  0899332757
# 21      5.0      True  03 22, 2015  A1SVV4QN08PMCC  0899332757
# 22      5.0      True   03 8, 2015  A3B1B4E184FSUZ  0899332757
# 23      5.0      True  02 25, 2015  A32HQVQQY3C254  0899332757
# 24      5.0      True  11 11, 2014  A1KND3NMYU2X1P  0899332757
# 25      5.0      True   11 9, 2014   ABZE5QBDXBI04  0899332757
# 26      4.0     False  06 18, 2013  A36RO7NCM6IUGB  0899332757
# 27      5.0      True   09 6, 2008  A377RL8VHY5ZFD  0899333257
# 28      5.0      True  02 15, 2007  A1T4WK0L835QHQ  0899333257
# 29      5.0      True   01 2, 2018  A15G1HRWLSDQ76  0899333257
# 30      5.0      True  12 15, 2017   AJU0DWGF2AOD4  0899333257
# 31      5.0      True   12 3, 2017   A7XCD6QB991OP  0899333257
# 32      5.0      True  10 26, 2017   ABWQ6YJ7SGT9F  0899333257
# 33      5.0      True  09 21, 2017   AWWZGVPKRQLO6  0899333257
# 34      5.0      True  09 15, 2017  A18UY0HNM3QHK6  0899333257
# 35      5.0      True  09 13, 2017   APR0HI8KAJ4QG  0899333257
# 36      5.0      True  07 20, 2017   AEJ4R3CCA7OQ9  0899333257
# 37      5.0      True  07 11, 2017  A3Q1T6QZZ1XNRS  0899333257
# 38      5.0      True  05 19, 2017  A1KX4ABDL4HJHZ  0899333257
# 39      5.0      True  04 20, 2017  A2N2GH5TEPAWNT  0899333257
# 40      4.0      True  03 13, 2017   ABZOB8SY43GYX  0899333257
# 41      1.0      True  02 12, 2017  A3TAI503QDDOVO  0899333257
# 42      4.0      True   09 2, 2016  A1950ESCHNVVGH  0899333257
# 43      5.0     False   08 8, 2016    A1LACH6MLQWZ  0899333257
# 44      5.0     False   08 2, 2016    A1LACH6MLQWZ  0899333257
# 45      5.0      True  07 14, 2016  A17DVWUVQBSNZB  0899333257
# 46      5.0      True  06 25, 2016  A1UB18R1N2MC69  0899333257
# 47      5.0      True  05 30, 2016  A2HXXCPZK1QO4Q  0899333257
# 48      5.0      True  03 30, 2016  A2KCG9PSTQBRNF  0899333257
# 49      5.0      True  03 14, 2016  A2W8SD7Z1TH6CR  0899333257
#
#            reviewerName                                         reviewText  \
# 0            Michelle A            What a spectacular tutu! Very slimming.
# 1             Crystal R  What the heck? Is this a tutu for nuns? I know...
# 2        darla Landreth                  Exactly what we were looking for!
# 3              L. Huynh  I used this skirt for a Halloween costume and ...
# 4               McKenna  This is thick enough that you can't see throug...
# 5       Amazon Customer  Already have an Atlas, topo CD set of Northeas...
# 6       Amazon Customer                                            So cool
# 7       Joseph Micallef       Arrived on time.  Nice Atlas - Easy to read.
# 8        jordan s moore  More of a road map than a useful topographical...
# 9       Gregory Mahnken  Comprehensive atlas. Very happy with how much ...
# 10   Love is all I have  Delorme has always made the best book maps in ...
# 11       Doug Erlandson  If you're interested in exploring any area of ...
# 12                   me                 worked great on the trip around ny
# 13         The Big Pill  I try to hike in the Catskills 2-3 times each ...
# 14      Corrina l dewey                                                map
# 15              ACS1978  Really, 4.5/5 stars. Missing a little detail w...
# 16              KennR72                    Arrived in tact and as expected
# 17         Jamie Moorby  These are the best maps, I get one for any sta...
# 18     Valerie T. Perez  Sure anyone can use GPS but on a road trip wit...
# 19       JOHN DE BELLAS  Wonderful, comprehensive atlas.  It's a little...
# 20          Big A train  Great product, FAST delivery! Just what we nee...
# 21        ruraltraveler  Great map - we use it to select scenic and var...
# 22              jobeck1                                                 A+
# 23     Jeffrey K. Baker                                          thank you
# 24               sharky  These are great for planning road trips especi...
# 25   Michael J. Perkins  These Gazetters are amazing! I own them for NY...
# 26   Long term customer  While perhaps not 100% accurate in extremely r...
# 27        Sonoran Woman  Arizona is a spectacular state.  There is so m...
# 28           A. Lashway  This is a must have for finding the tucked awa...
# 29        Stanley Lundy                                          great map
# 30               Ted B.        Fantastic detailed maps for all of Arizona.
# 31                  joe  Excellent, as always. My 5th DeLorme atlas. If...
# 32               jgrove  Great if you happen to need map information of...
# 33               Bob C.                                TOPO MAPS! YAY!!!!!
# 34         Todd Barrick  Though being a used book, it looks to be brand...
# 35                Luna4  I have a Delorme atlas for 11 US states. They'...
# 36                Romar                                             Useful
# 37            Tim Hibbs    Good product, arrived on time and as described.
# 38                Wayne  Absolutely essential for the "back roads" trav...
# 39             Carbon12  I love to travel some of the really back roads...
# 40   David J. Kunselman                                     as anticipated
# 41      Amazon Customer  I have purchased other Gazeteer's for other st...
# 42                   RW  I recently went on a long road trip to celebra...
# 43       Doug Erlandson  The first Delorme atlas and gazetteer I ever p...
# 44       Doug Erlandson  I purchased my first Delorme atlas and gazette...
# 45            Wallerish  This is a very useful general purpose atlas fo...
# 46                 LeeA  essential for any outdoor adventure planning, ...
# 47  Michael P. Mcsheehy  I like the Arizona Atlas and Gazetteer because...
# 48              Keven C                          Can't go wrong with these
# 49           johnny1329                 Excellent product excellent seller
#
#                                               summary  unixReviewTime  \
# 0                                          Five Stars      1433289600
# 1                           Is this a tutu for nuns?!      1427846400
# 2                                          Five Stars      1421107200
# 3   I liked that the elastic waist didn't dig in (...      1419292800
# 4   This is thick enough that you can't see throug...      1418601600
# 5                                         I love maps      1215216000
# 6                                             So cool      1486425600
# 7                           Nice Atlas - Easy to read      1482796800
# 8   Mostly a road atlas.  Well layed out and organ...      1481500800
# 9          Very happy with how much detail is in here      1471046400
# 10                                         Five Stars      1470096000
# 11   Great for exploring the rural parts of the state      1470009600
# 12                          for get gps lock at a map      1468454400
# 13  Smartphone nav apps don't always work in the b...      1464480000
# 14                                         Five Stars      1463011200
# 15                                    it's excellent.      1462924800
# 16                                         Five Stars      1445817600
# 17  These are the best maps, I get one for any sta...      1444176000
# 18                                Beyond the Horizon.      1440374400
# 19                                         Four Stars      1438646400
# 20                                             Super!      1432771200
# 21                                    Accurate, handy      1426982400
# 22                                         Five Stars      1425772800
# 23                                         Five Stars      1424822400
# 24  These are great for planning road trips especi...      1415664000
# 25  Better than online/smartphone apps if you can ...      1415491200
# 26                                        Good enough      1371513600
# 27                          Hit the Arizona Highways!      1220659200
# 28                          Arizona Atlas & Gazetteer      1171497600
# 29                                         Five Stars      1514851200
# 30                                          Great Map      1513296000
# 31                                    Great, as usual      1512259200
# 32                                         Five Stars      1508976000
# 33                                         Five Stars      1505952000
# 34                        Much better than advertised      1505433600
# 35                     Necessary for off grid camping      1505260800
# 36                                   Detailed, Useful      1500508800
# 37                                         Five Stars      1499731200
# 38                                     Indespensible!      1495152000
# 39  I love to travel some of the really back roads...      1492646400
# 40                                         Four Stars      1489363200
# 41                                Not worth any money      1486857600
# 42  A GPS is fine for driving.  But to plan your r...      1472774400
# 43                           Don't explore without it      1470614400
# 44                                       Great detail      1470096000
# 45                  Very Useful Atlas for Arizona....      1468454400
# 46                                          essential      1466812800
# 47        A Handy and Informative Guide for Travelers      1464566400
# 48                                         Five Stars      1459296000
# 49                                         Five Stars      1457913600
#
#                         style vote image
# 0                         NaN  NaN   NaN
# 1                         NaN  NaN   NaN
# 2                         NaN  NaN   NaN
# 3                         NaN  NaN   NaN
# 4                         NaN  NaN   NaN
# 5   {'Format:': ' Paperback'}  NaN   NaN
# 6   {'Format:': ' Paperback'}  NaN   NaN
# 7   {'Format:': ' Paperback'}  NaN   NaN
# 8   {'Format:': ' Paperback'}  NaN   NaN
# 9   {'Format:': ' Paperback'}  NaN   NaN
# 10  {'Format:': ' Paperback'}  NaN   NaN
# 11  {'Format:': ' Paperback'}  NaN   NaN
# 12  {'Format:': ' Paperback'}  NaN   NaN
# 13  {'Format:': ' Paperback'}    4   NaN
# 14  {'Format:': ' Paperback'}  NaN   NaN
# 15  {'Format:': ' Paperback'}  NaN   NaN
# 16  {'Format:': ' Paperback'}  NaN   NaN
# 17  {'Format:': ' Paperback'}  NaN   NaN
# 18  {'Format:': ' Paperback'}    2   NaN
# 19  {'Format:': ' Paperback'}  NaN   NaN
# 20  {'Format:': ' Paperback'}  NaN   NaN
# 21  {'Format:': ' Paperback'}  NaN   NaN
# 22  {'Format:': ' Paperback'}  NaN   NaN
# 23  {'Format:': ' Paperback'}  NaN   NaN
# 24  {'Format:': ' Paperback'}  NaN   NaN
# 25  {'Format:': ' Paperback'}  NaN   NaN
# 26  {'Format:': ' Paperback'}  NaN   NaN
# 27  {'Format:': ' Paperback'}  NaN   NaN
# 28  {'Format:': ' Paperback'}  NaN   NaN
# 29  {'Format:': ' Paperback'}  NaN   NaN
# 30  {'Format:': ' Paperback'}  NaN   NaN
# 31  {'Format:': ' Paperback'}  NaN   NaN
# 32  {'Format:': ' Paperback'}  NaN   NaN
# 33  {'Format:': ' Paperback'}  NaN   NaN
# 34  {'Format:': ' Paperback'}  NaN   NaN
# 35  {'Format:': ' Paperback'}  NaN   NaN
# 36  {'Format:': ' Paperback'}  NaN   NaN
# 37  {'Format:': ' Paperback'}  NaN   NaN
# 38  {'Format:': ' Paperback'}    3   NaN
# 39  {'Format:': ' Paperback'}  NaN   NaN
# 40  {'Format:': ' Paperback'}  NaN   NaN
# 41                        NaN    5   NaN
# 42  {'Format:': ' Paperback'}    3   NaN
# 43                        NaN  NaN   NaN
# 44  {'Format:': ' Paperback'}  NaN   NaN
# 45                        NaN  NaN   NaN
# 46  {'Format:': ' Paperback'}  NaN   NaN
# 47                        NaN  NaN   NaN
# 48  {'Format:': ' Paperback'}  NaN   NaN
# 49  {'Format:': ' Paperback'}  NaN   NaN

# %%
df['overall'].value_counts()
# Out:
# 5.0    1921398
# 4.0     495533
# 3.0     210215
# 1.0     111157
# 2.0     101637
# Name: overall, dtype: int64

# %%
df['verified'].value_counts()
# Out:
# True     2611805
# False     228135
# Name: verified, dtype: int64

# %%
len(df)
# Out:
# 2839940
